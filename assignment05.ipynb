# %% [markdown]
# # This is assignment05
#
# ## Name : Jaehyun Lim
#
# ## Student ID : 20145450

# %% [markdown]
# ## Defi􏰀nition of the convolution kernel for computing the derivative in x-direction

# %% [markdown]
# $$\frac{\partial f}{\partial x} = \lim_{h \to \infty} \frac{(x+h)+f(x)}{h}  \Rightarrow  kernel = \begin{bmatrix} 1&\ -1 \end{bmatrix} $$

# %% [markdown]
# ## Defi􏰀nition of the convolution kernel for computing the derivative in y-direction

# %% [markdown]
# $$\frac{\partial f}{\partial x} = \lim_{h \to \infty} \frac{(x+h)+f(x)}{h}  \Rightarrow  kernel = \begin{bmatrix} 1 \\ -1 \end{bmatrix}$$

# %% [markdown]
# ## import packages

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal
from skimage import io, color
from skimage import exposure
import pylab

# %% [markdown]
# ## Load the image

# %%
im_color = io.imread('cau.jpg') 
plt.imshow(im_color)
plt.axis('off')
plt.show()

# %% [markdown]
# ## Convert the image to grayscale

# %%
im_gray = color.rgb2gray(im_color)  
plt.imshow(im_gray, cmap='gray')
plt.axis('off')
plt.show()

# %% [markdown]
# ## Function : return convolution of image and kernel

# %%
def convolution(image, kernel):
  
    kernel = np.flipud(np.fliplr(kernel))    
    output = np.zeros_like(image)           
    image_padded = np.zeros((image.shape[0] + 2, image.shape[1] + 2))   
    image_padded[1:-1, 1:-1] = image
    for x in range(image.shape[1]):     
        for y in range(image.shape[0]):
            output[y,x]=(kernel*image_padded[y:y+3,x:x+3]).sum()        
    return output

# %% [markdown]
# ## Smoothing kernel

# %%
kernel = np.array([[0,0,0],[0,1,0],[0,-0.5,0.3]])
image = convolution(im_gray,kernel)
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.show()

# %% [markdown]
# ## My kernel
# ### Color inversion image

# %%
kernel = np.array([[-1,-1,-1],[0,1,0],[-1,-1,-1]])
image = convolution(im_gray,kernel)
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.show()
